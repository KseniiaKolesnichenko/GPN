# %%
import pandas as pd
from os import listdir
from os.path import isfile, join


DATA_DIR = './data'
files = [f for f in listdir(DATA_DIR) if isfile(join(DATA_DIR, f))]

df = pd.DataFrame()
for f in files:
    file = pd.read_csv(join(DATA_DIR, f),  skip_blank_lines=True)
    file['University'] = f.split('.csv')[0]
    try:
        df = df.append(file, ignore_index=True)
    except IndexError:
        df = file

print(df.head())
print(df.tail())
# Out:
#                                                Title  ... University
# 0  The Simons Genome Diversity Project: 300 genom...  ...      БашГУ
# 1  Association analysis identifies 65 new breast ...  ...      БашГУ
# 2  Prediction of breast cancer risk based on prof...  ...      БашГУ
# 3  Genomic evidence for the Pleistocene and recen...  ...      БашГУ
# 4  Genomic analyses inform on migration events du...  ...      БашГУ
#
# [5 rows x 30 columns]
#                                                   Title  ... University
# 1875  Harmony search algorithm for chemical kinetics...  ...      БашГУ
# 1876  River runoff variability at watercourses of th...  ...      БашГУ
# 1877  On inverse spectral problem and generalized st...  ...      БашГУ
# 1878      Problems of the legal status of private farms  ...      БашГУ
# 1879  Legal problems of peasant farm enterprise acti...  ...      БашГУ
#
# [5 rows x 30 columns]

# %%
df
# Out:
#                                                   Title  ... University
# 0     The Simons Genome Diversity Project: 300 genom...  ...      БашГУ
# 1     Association analysis identifies 65 new breast ...  ...      БашГУ
# 2     Prediction of breast cancer risk based on prof...  ...      БашГУ
# 3     Genomic evidence for the Pleistocene and recen...  ...      БашГУ
# 4     Genomic analyses inform on migration events du...  ...      БашГУ
# ...                                                 ...  ...        ...
# 1875  Harmony search algorithm for chemical kinetics...  ...      БашГУ
# 1876  River runoff variability at watercourses of th...  ...      БашГУ
# 1877  On inverse spectral problem and generalized st...  ...      БашГУ
# 1878      Problems of the legal status of private farms  ...      БашГУ
# 1879  Legal problems of peasant farm enterprise acti...  ...      БашГУ
#
# [1880 rows x 30 columns]

# %%
def replace_l_to_series (a): #превращает список строки датафрейма в сериес
  return a.split('| ')

# %%
df.columns
# Out:
# Index(['Title', 'Authors', 'Number of Authors', 'Scopus Author Ids', 'Year',
#        'Scopus Source title', 'Field-Weighted View Impact', 'Views',
#        'Citations', 'Field-Weighted Citation Impact',
#        'Outputs in Top Citation Percentiles, per percentile',
#        'Field-Weighted Outputs in Top Citation Percentiles, per percentile',
#        'Reference', 'Abstract', 'DOI', 'Publication type', 'EID',
#        'Institutions', 'Scopus Affiliation IDs', 'Scopus Affiliation names',
#        'Country/Region', 'All Science Journal Classification (ASJC) code',
#        'All Science Journal Classification (ASJC) field name',
#        'Topic Cluster name', 'Topic Cluster number', 'Topic name',
#        'Topic number', 'Topic Cluster Prominence Percentile',
#        'Topic Prominence Percentile', 'University'],
#       dtype='object')

# %%
df1 = df['Country/Region']

# %%
df['Country/Region'] = df['Country/Region'].map(replace_l_to_series)

# %%
df1 = df['Country/Region']

# %%
df1
# Out:
# 0       [India, United Kingdom, Kenya, Spain, Mexico, ...
# 1       [Spain, Hong Kong, Thailand, Denmark, Taiwan, ...
# 2       [United Kingdom, Spain, Finland, Denmark, Ital...
# 3       [Chile, United Kingdom, Mexico, Spain, France,...
# 4       [United Kingdom, Albania, Brunei Darussalam, D...
#                               ...
# 1875                                 [Russian Federation]
# 1876                                 [Russian Federation]
# 1877                         [Russian Federation, Brazil]
# 1878                                 [Russian Federation]
# 1879                                 [Russian Federation]
# Name: Country/Region, Length: 1880, dtype: object

# %%
df
# Out:
#                                                   Title  ... University
# 0     The Simons Genome Diversity Project: 300 genom...  ...      БашГУ
# 1     Association analysis identifies 65 new breast ...  ...      БашГУ
# 2     Prediction of breast cancer risk based on prof...  ...      БашГУ
# 3     Genomic evidence for the Pleistocene and recen...  ...      БашГУ
# 4     Genomic analyses inform on migration events du...  ...      БашГУ
# ...                                                 ...  ...        ...
# 1875  Harmony search algorithm for chemical kinetics...  ...      БашГУ
# 1876  River runoff variability at watercourses of th...  ...      БашГУ
# 1877  On inverse spectral problem and generalized st...  ...      БашГУ
# 1878      Problems of the legal status of private farms  ...      БашГУ
# 1879  Legal problems of peasant farm enterprise acti...  ...      БашГУ
#
# [1880 rows x 30 columns]

# %%
import numpy as np
coun = pd.DataFrame()
coun = np.unique(df1.values) 
coun.tolist()
# Out:
# [['Armenia', 'France', 'Russian Federation', 'Estonia'],
#  ['Armenia', 'France', 'Russian Federation', 'Estonia', 'Belarus'],
#  ['Armenia', 'Russian Federation', 'Estonia', 'Hungary'],
#  ['Australia', 'France', 'Russian Federation'],
#  ['Australia', 'Russian Federation'],
#  ['Austria', 'Germany', 'Russian Federation'],
#  ['Austria',
#   'Spain',
#   'Denmark',
#   'Hungary',
#   'Belgium',
#   'Latvia',
#   'Israel',
#   'Poland',
#   'United States',
#   'Germany',
#   'Iceland',
#   'Colombia',
#   'Greece',
#   'Netherlands',
#   'Sweden',
#   'United Kingdom',
#   'Finland',
#   'South Africa',
#   'France',
#   'Italy',
#   'North Macedonia',
#   'Cyprus',
#   'Bulgaria',
#   'Brazil',
#   'South Korea',
#   'China',
#   'Norway',
#   'Portugal',
#   'Australia',
#   'Russian Federation',
#   'Belarus',
#   'Canada'],
#  ['Austria',
#   'Spain',
#   'Denmark',
#   'Hungary',
#   'Belgium',
#   'Latvia',
#   'Israel',
#   'Poland',
#   'United States',
#   'Iceland',
# ...

# %%
type(coun)
# Out:
# numpy.ndarray

# %%
country = []
for val in coun:
  for i in val:
    country.append(i)

# %%
country = np.unique(country)

# %%
country
# Out:
# array(['Albania', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahrain', 'Bangladesh', 'Belarus', 'Belgium',
#        'Bosnia and Herzegovina', 'Brazil', 'Brunei Darussalam',
#        'Bulgaria', 'Cameroon', 'Canada', 'Chile', 'China', 'Colombia',
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Egypt',
#        'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kenya',
#        'Kyrgyzstan', 'Latvia', 'Lebanon', 'Lithuania', 'Malaysia',
#        'Malta', 'Mexico', 'Moldova', 'Mongolia', 'Netherlands',
#        'New Zealand', 'North Macedonia', 'Norway', 'Pakistan', 'Peru',
#        'Poland', 'Portugal', 'Romania', 'Russian Federation',
#        'Saudi Arabia', 'Serbia', 'Singapore', 'Slovakia', 'Slovenia',
#        'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland',
# ...

# %%
country1= pd.DataFrame( columns = country)

# %%
df_country = df

# %%
df_country = df_country.join(country1)

# %%
df_country
# Out:
#                                                   Title  ... Viet Nam
# 0     The Simons Genome Diversity Project: 300 genom...  ...      NaN
# 1     Association analysis identifies 65 new breast ...  ...      NaN
# 2     Prediction of breast cancer risk based on prof...  ...      NaN
# 3     Genomic evidence for the Pleistocene and recen...  ...      NaN
# 4     Genomic analyses inform on migration events du...  ...      NaN
# ...                                                 ...  ...      ...
# 1875  Harmony search algorithm for chemical kinetics...  ...      NaN
# 1876  River runoff variability at watercourses of th...  ...      NaN
# 1877  On inverse spectral problem and generalized st...  ...      NaN
# 1878      Problems of the legal status of private farms  ...      NaN
# 1879  Legal problems of peasant farm enterprise acti...  ...      NaN
#
# [1880 rows x 109 columns]

# %%
column_names = df_country.columns[30:109]

# %%
 i = 0

for str in df_country['Country/Region']:
  for  name in column_names:
    if name in str:
      df_country.loc[i, name] = 1
    else:
      df_country.loc[i, name] = 0
  i+=1

# %%
df_country.head(20)
# Out:
#                                                 Title  ... Viet Nam
# 0   The Simons Genome Diversity Project: 300 genom...  ...        0
# 1   Association analysis identifies 65 new breast ...  ...        0
# 2   Prediction of breast cancer risk based on prof...  ...        0
# 3   Genomic evidence for the Pleistocene and recen...  ...        0
# 4   Genomic analyses inform on migration events du...  ...        0
# 5   Global diversity, population stratification, a...  ...        0
# 6   A recent bottleneck of Y chromosome diversity ...  ...        0
# 7   Polygenic Risk Scores for Prediction of Breast...  ...        0
# 8   Multiancestry association study identifies new...  ...        0
# 9   Identification of 12 new susceptibility loci f...  ...        0
# 10  Identification of ten variants associated with...  ...        0
# 11  Age-And tumor subtype-specific breast cancer r...  ...        0
# 12  The Genetic Legacy of the Expansion of Turkic-...  ...        0
# ...

# %%
df_cluster_name = df['Topic Cluster name']

# %%
def replace_l_to_series2 (a): #превращает список строки датафрейма в сериес
  return a.split(',')

# %%
df_cluster_name['Topic Cluster name'] = df['Topic Cluster name'].map(replace_l_to_series2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_cluster_name['Topic Cluster name']
# Out:
# 0               [DNA, Microsatellite Repeats, Population]
# 1               [Breast Neoplasms, Genetic Testing, Risk]
# 2               [Breast Neoplasms, Genetic Testing, Risk]
# 3               [DNA, Microsatellite Repeats, Population]
# 4               [DNA, Microsatellite Repeats, Population]
#                               ...
# 1875    [Optimization, Algorithms, Evolutionary Algori...
# 1876                         [Parasites, Fishes, Myxozoa]
# 1877    [Schrödinger Operator, Eigenvalue, Sturm-Liouv...
# 1878                           [Food, Consumers, Farmers]
# 1879                          [China, Chinese, Hong Kong]
# Name: Topic Cluster name, Length: 1880, dtype: object

# %%
cluster_name = []
cluster_name = np.unique(df_cluster_name['Topic Cluster name'])
cluster_name
# Out:
# array([list(['-']), list(['Accident Prevention', 'Hazards', 'Accidents']),
#        list(['Acids', 'Triterpenes', 'Oleanolic Acid']),
#        list(['Acoustics', 'Architectural Acoustics', 'Acoustic Waves']),
#        list(['Additives', 'Manufacture', 'Printing']),
#        list(['Adsorption', 'Adsorbents', 'Activated Carbon']),
#        list(['Aerosols', 'Air Quality', 'Atmospheric Aerosols']),
#        list(['Africa', 'African', 'South Africa']),
#        list(['Alcohols', 'Reward', 'Cocaine']),
#        list(['Alfalfa', 'Forage', 'Lolium Perenne']),
#        list(['Algae', 'Microalgae', 'Biodiesel']),
#        list(['Algebra', 'Category', 'Module']),
#        list(['Algorithms', 'Computer Vision', 'Models']),
#        list(['Alkaloids', 'Indole Alkaloids', 'Carbolines']),
#        list(['Allergens', 'Hypersensitivity', 'Atopic Dermatitis']),
#        list(['Amines', 'Carbon Dioxide', 'Flue Gases']),
#        list(['Amphipoda', 'Crustacea', 'Isopoda']),
# ...

# %%
#cluster_name1 = []
#for val in cluster_name:
#   cluster_name1.append(val)
#cluster_name1
# Out:
# [['-'],
#  ['Accident Prevention', 'Hazards', 'Accidents'],
#  ['Acids', 'Triterpenes', 'Oleanolic Acid'],
#  ['Acoustics', 'Architectural Acoustics', 'Acoustic Waves'],
#  ['Additives', 'Manufacture', 'Printing'],
#  ['Adsorption', 'Adsorbents', 'Activated Carbon'],
#  ['Aerosols', 'Air Quality', 'Atmospheric Aerosols'],
#  ['Africa', 'African', 'South Africa'],
#  ['Alcohols', 'Reward', 'Cocaine'],
#  ['Alfalfa', 'Forage', 'Lolium Perenne'],
#  ['Algae', 'Microalgae', 'Biodiesel'],
#  ['Algebra', 'Category', 'Module'],
#  ['Algorithms', 'Computer Vision', 'Models'],
#  ['Alkaloids', 'Indole Alkaloids', 'Carbolines'],
#  ['Allergens', 'Hypersensitivity', 'Atopic Dermatitis'],
#  ['Amines', 'Carbon Dioxide', 'Flue Gases'],
#  ['Amphipoda', 'Crustacea', 'Isopoda'],
#  ['Aneurysm', 'Intracranial Aneurysm', 'Subarachnoid Hemorrhage'],
#  ['Anodes', 'Electrolysis', 'Molten Materials'],
#  ['Anti-Bacterial Agents',
#   'Infection',
#   'Methicillin-Resistant Staphylococcus Aureus'],
# ...

# %%
cluster_name2 = []
for val in cluster_name:
  for i in val:
    cluster_name2.append(i)
cluster_name2
# Out:
# ['-',
#  'Accident Prevention',
#  'Hazards',
#  'Accidents',
#  'Acids',
#  'Triterpenes',
#  'Oleanolic Acid',
#  'Acoustics',
#  'Architectural Acoustics',
#  'Acoustic Waves',
#  'Additives',
#  'Manufacture',
#  'Printing',
#  'Adsorption',
#  'Adsorbents',
#  'Activated Carbon',
#  'Aerosols',
#  'Air Quality',
#  'Atmospheric Aerosols',
#  'Africa',
#  'African',
#  'South Africa',
#  'Alcohols',
#  'Reward',
#  'Cocaine',
#  'Alfalfa',
#  'Forage',
#  'Lolium Perenne',
#  'Algae',
#  'Microalgae',
#  'Biodiesel',
#  'Algebra',
#  'Category',
#  'Module',
#  'Algorithms',
#  'Computer Vision',
#  'Models',
#  'Alkaloids',
#  'Indole Alkaloids',
#  'Carbolines',
#  'Allergens',
#  'Hypersensitivity',
#  'Atopic Dermatitis',
#  'Amines',
#  'Carbon Dioxide',
#  'Flue Gases',
#  'Amphipoda',
#  'Crustacea',
#  'Isopoda',
#  'Aneurysm',
#  'Intracranial Aneurysm',
#  'Subarachnoid Hemorrhage',
#  'Anodes',
#  'Electrolysis',
#  'Molten Materials',
#  'Anti-Bacterial Agents',
# ...

# %%
cluster_name2 = np.unique(cluster_name2)

# %%
len(cluster_name2)
# Out:
# 1104

# %%
len(set(cluster_name2))
# Out:
# 1104

# %%
cluster_name_columns = pd.DataFrame( columns = cluster_name2)

# %%
df_cluster_name = df.join(cluster_name_columns)

# %%
df_cluster_name.head(6)
# Out:
#                                                Title  ... Zircon
# 0  The Simons Genome Diversity Project: 300 genom...  ...    NaN
# 1  Association analysis identifies 65 new breast ...  ...    NaN
# 2  Prediction of breast cancer risk based on prof...  ...    NaN
# 3  Genomic evidence for the Pleistocene and recen...  ...    NaN
# 4  Genomic analyses inform on migration events du...  ...    NaN
# 5  Global diversity, population stratification, a...  ...    NaN
#
# [6 rows x 1134 columns]

# %%
 # не запускать на большой выборке, долго выполняется
 
 i = 0

for str in df_cluster_name['Topic Cluster name']:
  for  name in cluster_name2:
    if name in str:
      df_cluster_name.loc[i, name] = 1
    else:
      df_cluster_name.loc[i, name] = 0
  i+=1

# %%
df_cluster_name.head(5)
# Out:
#                                                Title  ... Zircon
# 0  The Simons Genome Diversity Project: 300 genom...  ...      0
# 1  Association analysis identifies 65 new breast ...  ...      0
# 2  Prediction of breast cancer risk based on prof...  ...      0
# 3  Genomic evidence for the Pleistocene and recen...  ...      0
# 4  Genomic analyses inform on migration events du...  ...      0
#
# [5 rows x 1134 columns]

# %%
df_cluster_name.tail(15)
# Out:
#                                                   Title  ... Zircon
# 1865  Publisher Correction: Shared heritability and ...  ...      0
# 1866  Characteristics of CART Peptide-Immunopositive...  ...      0
# 1867  Metrological Aspects of Measuring the Volume-A...  ...      0
# 1868  The particular features of students’ scholarly...  ...      0
# 1869  Equivalence of Entropy and Renormalized Soluti...  ...      0
# 1870  Analysis and evaluation of formation schemes o...  ...      0
# 1871  Audiovisual correction of the psychoemotional ...  ...      0
# 1872  Experience of thermo-hydrodynamic studies of w...  ...      0
# 1873  Modern pension provision system as a social in...  ...      0
# 1874  Genetic diversity and differentiation among po...  ...      0
# 1875  Harmony search algorithm for chemical kinetics...  ...      0
# 1876  River runoff variability at watercourses of th...  ...      0
# 1877  On inverse spectral problem and generalized st...  ...      0
# ...

# %%
df_topic_name = df['Topic name']

# %%
df_topic_name['Topic name'] = df['Topic name'].map(replace_l_to_series2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
topic_name = []
topic_name = np.unique(df_topic_name['Topic name'])
topic_name
# Out:
# array([list(['-']),
#        list(['1-Aminocyclopropane-1-Carboxylate Deaminase', 'Plant Growth-promoting Rhizobacteria', 'Rhizosphere Bacterium']),
#        list(['15-Deoxy-Delta(12', '14)-Prostaglandin J2', 'Rosiglitazone', 'PPAR Gamma']),
#        list(['2 Hydroxypropyl Beta Cyclodextrin', 'Cyclodextrins', 'Complexation']),
#        list(["2'-disulfonic Acid 1-amino-8-nephthol-2", 'Cationic Polymerization', 'Pka']),
#        list(['3-Vinyl-1', '2', '4-Triazine', 'Amyl Nitrite', 'Cyclopentanes']),
#        list(['3D Printers', 'Spare Parts', 'Manufacturing Technology']),
#        list(['4-Chlorophenol', 'Particle Diffusion', 'Adsorbents']),
#        list(['5-Aminopyrazole', '(1', '2', '4)triazolo(1', '5-a)(1', '3', '5)triazine', 'Cyanamides']),
#        list(['5-Aminouracil', 'Uracil Derivatives', 'Thymine']),
#        list(['5-Chlorouracil', 'Uracil', 'Thymine']),
#        list(['AF Losev', 'Mikhail Bakhtin', 'Russian Formalism']),
# ...

# %%
#очень много для dummy

topic_name2 = []
for val in topic_name:
  for i in val:
    topic_name2.append(i)
len(topic_name2)
# Out:
# 2491
