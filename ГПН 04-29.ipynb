# %%
import pandas as pd
from os import listdir
from os.path import isfile, join


DATA_DIR = './data'
files = [f for f in listdir(DATA_DIR) if isfile(join(DATA_DIR, f))]

df = pd.DataFrame()
for f in files:
    file = pd.read_csv(join(DATA_DIR, f),  skip_blank_lines=True)
    file['University'] = f.split('.csv')[0]
    try:
        df = df.append(file, ignore_index=True)
    except IndexError:
        df = file

print(df.head())
print(df.tail())
# Out:
#                                                Title  \
# 0  The Simons Genome Diversity Project: 300 genom...
# 1  Association analysis identifies 65 new breast ...
# 2  Prediction of breast cancer risk based on prof...
# 3  Genomic evidence for the Pleistocene and recen...
# 4  Genomic analyses inform on migration events du...
#
#                                              Authors  Number of Authors  \
# 0  Mallick, S.| Li, H.| Lipson, M.| Mathieson, I....                 79
# 1  Michailidou, K.| Lindström, S.| Dennis, J.| Be...                362
# 2  Mavaddat, N.| Pharoah, P.D.P.| Michailidou, K....                212
# 3  Raghavan, M.| Steinrücken, M.| Harris, K.| Sch...                101
# 4  Pagani, L.| Lawson, D.J.| Jagoda, E.| Mörsebur...                 97
#
#                                    Scopus Author Ids  Year  \
# 0  24339060900| 12777127000| 55489570100| 5492219...  2016
# 1  57194780971| 57193814735| 57197867113| 5722046...  2017
# ...

# %%
df
# Out:
#                                                     Title  \
# 0       The Simons Genome Diversity Project: 300 genom...
# 1       Association analysis identifies 65 new breast ...
# 2       Prediction of breast cancer risk based on prof...
# 3       Genomic evidence for the Pleistocene and recen...
# 4       Genomic analyses inform on migration events du...
# ...                                                   ...
# 297472  Grain crop defect fixing method based on digit...
# 297473  X-RAY NANOPHOSPHORS BASED ON BaGdF5 FOR X-RAY ...
# 297474  ASSESSMENT OF THE LEVEL OF ANXIETY AS AN INDIC...
# 297475  Improvement of environmental indicators of coa...
# 297476  Interpretation of trialectic meaning-making st...
#
#                                                   Authors  Number of Authors  \
# 0       Mallick, S.| Li, H.| Lipson, M.| Mathieson, I....                 79
# 1       Michailidou, K.| Lindström, S.| Dennis, J.| Be...                362
# ...

# %%
print(df.head())
# Out:
#                                                Title  \
# 0  The Simons Genome Diversity Project: 300 genom...
# 1  Association analysis identifies 65 new breast ...
# 2  Prediction of breast cancer risk based on prof...
# 3  Genomic evidence for the Pleistocene and recen...
# 4  Genomic analyses inform on migration events du...
#
#                                              Authors  Number of Authors  \
# 0  Mallick, S.| Li, H.| Lipson, M.| Mathieson, I....                 79
# 1  Michailidou, K.| Lindström, S.| Dennis, J.| Be...                362
# 2  Mavaddat, N.| Pharoah, P.D.P.| Michailidou, K....                212
# 3  Raghavan, M.| Steinrücken, M.| Harris, K.| Sch...                101
# 4  Pagani, L.| Lawson, D.J.| Jagoda, E.| Mörsebur...                 97
#
#                                    Scopus Author Ids  Year  \
# 0  24339060900| 12777127000| 55489570100| 5492219...  2016
# 1  57194780971| 57193814735| 57197867113| 5722046...  2017
# ...

# %%
list(df)
# Out:
# ['Title',
#  'Authors',
#  'Number of Authors',
#  'Scopus Author Ids',
#  'Year',
#  'Scopus Source title',
#  'Field-Weighted View Impact',
#  'Views',
#  'Citations',
#  'Field-Weighted Citation Impact',
#  'Outputs in Top Citation Percentiles, per percentile',
#  'Field-Weighted Outputs in Top Citation Percentiles, per percentile',
#  'Reference',
#  'Abstract',
#  'DOI',
#  'Publication type',
#  'EID',
#  'Institutions',
#  'Scopus Affiliation IDs',
#  'Scopus Affiliation names',
#  'Country/Region',
#  'All Science Journal Classification (ASJC) code',
#  'All Science Journal Classification (ASJC) field name',
#  'Topic Cluster name',
#  'Topic Cluster number',
#  'Topic name',
#  'Topic number',
#  'Topic Cluster Prominence Percentile',
#  'Topic Prominence Percentile',
#  'University']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297477 entries, 0 to 297476
# Data columns (total 30 columns):
#  #   Column                                                              Non-Null Count   Dtype
# ---  ------                                                              --------------   -----
#  0   Title                                                               297477 non-null  object
#  1   Authors                                                             297475 non-null  object
#  2   Number of Authors                                                   297477 non-null  int64
#  3   Scopus Author Ids                                                   297477 non-null  object
#  4   Year                                                                297477 non-null  int64
#  5   Scopus Source title                                                 297477 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Title                                                                 0
# Authors                                                               2
# Number of Authors                                                     0
# Scopus Author Ids                                                     0
# Year                                                                  0
# Scopus Source title                                                   0
# Field-Weighted View Impact                                            0
# Views                                                                 0
# Citations                                                             0
# Field-Weighted Citation Impact                                        0
# Outputs in Top Citation Percentiles, per percentile                   0
# Field-Weighted Outputs in Top Citation Percentiles, per percentile    0
# Reference                                                             0
# ...

# %%
df['Topic Cluster number']
# Out:
# 0          604
# 1          587
# 2          587
# 3          604
# 4          604
#           ...
# 297472     451
# 297473      91
# 297474     665
# 297475    1426
# 297476    1114
# Name: Topic Cluster number, Length: 297477, dtype: object

# %%
df['Field-Weighted Citation Impact']
# Out:
# 0         16.98
# 1         20.68
# 2         11.95
# 3          7.49
# 4          7.78
#           ...
# 297472     0.00
# 297473     0.00
# 297474     0.00
# 297475     0.00
# 297476     0.00
# Name: Field-Weighted Citation Impact, Length: 297477, dtype: float64

# %%
max(df['Field-Weighted Citation Impact'])
# Out:
# 838.09

# %%
min(df['Field-Weighted Citation Impact'])
# Out:
# 0.0

# %%
#Вот тут файл сохраняется в Эксель
writer = pd.ExcelWriter('output.xlsx')
df.to_excel(writer)
writer.save()
